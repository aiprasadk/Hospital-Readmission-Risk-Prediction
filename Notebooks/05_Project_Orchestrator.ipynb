# %% [markdown]
# # Project Orchestration
#
# This notebook represents the final orchestration layer of the Databricks Job.
# Execution is managed via a multi-task Databricks Job that runs the pipeline
# from Bronze ingestion to ML prediction and analytics.

# %%
print("Starting Bronze Layer")

dbutils.notebook.run(
    "/Users/aiprasadk@gmail.com/hospital_readmission_pipeline/01_Bronze_Raw_Data_Ingestion",
    timeout_seconds=0
)

print("Starting Silver Layer")

dbutils.notebook.run(
    "/Users/aiprasadk@gmail.com/hospital_readmission_pipeline/02_Silver_Data_Cleaning",
    timeout_seconds=0
)

print("Starting Gold Layer")

dbutils.notebook.run(
    "/Users/aiprasadk@gmail.com/hospital_readmission_pipeline/03_Gold_Feature_Engineering",
    timeout_seconds=0
)

print("Starting Model Training")

dbutils.notebook.run(
    "/Users/aiprasadk@gmail.com/hospital_readmission_pipeline/04_Model_Training_MLflow",
    timeout_seconds=0
)

print("Pipeline completed successfully")
# Out:
# Starting Bronze Layer
# Starting Silver Layer
# Starting Gold Layer
# Starting Model Training
# Pipeline completed successfully
